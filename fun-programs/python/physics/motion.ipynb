# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def linear(u, a, t):
    '''
    u: init velocity (m/s)
    a: acc (m/s^2)
    t: time (s) 

    return velocity for an object in motion at time t
    '''
    return u + a*t

v = linear(10, 2, 100)
print(f"v = {v} m/s")
# Out:
# v = 210 m/s

# %%
# velocity time graph for linear motion
vel = []
t_s = []
for i in range(100):
    v_calc = linear(10, 2, i)
    vel.append(v_calc)
    t_s.append(i)

# print(vel)
# print(t_s)
plt.plot(t_s, vel)

# %%
# second equation of motion

def second_eqn(v0, t, a):
    '''
    v0: initial velocity (m/s)
    t : time (s)
    a : accelaration (m/s^2)
    '''
    return v0*t + 0.5*a*t**2

disp = second_eqn(v0=0, t=6, a=2)
print(f"displacement = {disp} m")
# Out:
# displacement = 36.0 m

# %%
disp_pts = []
t_stamps = []

for i in range(100):
    disp_calc = second_eqn(0, i, 2)
    disp_pts.append(disp_calc)
    t_stamps.append(i)

print(disp_pts)
print(t_stamps)

plt.plot(t_stamps, disp_pts)
# Out:
# [0.0, 1.0, 4.0, 9.0, 16.0, 25.0, 36.0, 49.0, 64.0, 81.0, 100.0, 121.0, 144.0, 169.0, 196.0, 225.0, 256.0, 289.0, 324.0, 361.0, 400.0, 441.0, 484.0, 529.0, 576.0, 625.0, 676.0, 729.0, 784.0, 841.0, 900.0, 961.0, 1024.0, 1089.0, 1156.0, 1225.0, 1296.0, 1369.0, 1444.0, 1521.0, 1600.0, 1681.0, 1764.0, 1849.0, 1936.0, 2025.0, 2116.0, 2209.0, 2304.0, 2401.0, 2500.0, 2601.0, 2704.0, 2809.0, 2916.0, 3025.0, 3136.0, 3249.0, 3364.0, 3481.0, 3600.0, 3721.0, 3844.0, 3969.0, 4096.0, 4225.0, 4356.0, 4489.0, 4624.0, 4761.0, 4900.0, 5041.0, 5184.0, 5329.0, 5476.0, 5625.0, 5776.0, 5929.0, 6084.0, 6241.0, 6400.0, 6561.0, 6724.0, 6889.0, 7056.0, 7225.0, 7396.0, 7569.0, 7744.0, 7921.0, 8100.0, 8281.0, 8464.0, 8649.0, 8836.0, 9025.0, 9216.0, 9409.0, 9604.0, 9801.0]
# ...

# %%
# an object falling from 10 m with an init vel of 0m/s and a = 9.8 m/s^2

def obj_fall(u, t, g=9.8):
    '''
    u: init velocity (m/s)
    t: time (s)
    '''
    return u + g*t

v_at_t = obj_fall(10, 3)
print(f"velocity at t = 3 seconds : {v_at_t:0.3f} m/s")
# Out:
# velocity at t = 3 seconds : 39.400 m/s

# %%
def simple_harmonic(A, omega, t, phi):
    '''
    A     : amplitude (m)
    omega : angular frequency (rad / s)
    t     : time (s)
    phi   : phase angle (rad)
    '''
    return float(A * np.cos(omega*t + phi))

shm = simple_harmonic(0.10, 20, 0.05, 0)
print(f"X = {shm:0.5f} m")
# Out:
# X = 0.05403 m

# %%
shm_pts = []
t_pts   = []

for i in range(150):
    x_calc = simple_harmonic(0.10, 20, i, 0)
    shm_pts.append(x_calc)
    t_pts.append(i)

plt.plot(t_pts, shm_pts)

# %%
def projectile():
    pass

# %%
def circular():
    pass

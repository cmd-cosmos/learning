# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def linear(u, a, t):
    '''
    u: init velocity (m/s)
    a: acc (m/s^2)
    t: time (s) 

    return velocity for an object in motion at time t
    '''
    return u + a*t

v = linear(10, 2, 100)
print(f"v = {v} m/s")
# Out:
# v = 210 m/s

# %%
def projectile():
    pass

# %%
def harmonic():
    pass

# %%
def circular():
    pass

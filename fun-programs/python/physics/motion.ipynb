# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def linear(u, a, t):
    '''
    u: init velocity (m/s)
    a: acc (m/s^2)
    t: time (s) 

    return velocity for an object in motion at time t
    '''
    return u + a*t

v = linear(10, 2, 100)
print(f"v = {v} m/s")
# Out:
# v = 210 m/s

# %%
# velocity time graph for linear motion
vel = []
t_s = []
for i in range(100):
    v_calc = linear(10, 2, i)
    vel.append(v_calc)
    t_s.append(i)

# print(vel)
# print(t_s)
plt.plot(vel, t_s)

# %%
# second equation of motion

def second_eqn(v0, t, a):
    '''
    v0: initial velocity (m/s)
    t : time (s)
    a : accelaration (m/s^2)
    '''
    return v0*t + 0.5*a*t**2

disp = second_eqn(v0=0, t=6, a=2)
print(f"displacement = {disp} m")
# Out:
# displacement = 36.0 m

# %%
def projectile():
    pass

# %%
def harmonic():
    pass

# %%
def circular():
    pass

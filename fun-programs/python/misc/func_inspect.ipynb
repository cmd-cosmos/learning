# %%
#type:ignore

import traceback
import inspect

try:
    def a():
        b()
    def b():
        c()
    def c():
        1 / 0
    a()

except Exception:
    traceback.print_stack()
    traceback.print_exc()
# Out:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Python313\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Python313\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Python313\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Python313\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "c:\Python313\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "c:\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Python313\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
# ...

# %%
# curr stack

stack = inspect.stack()
for frame_info in stack:
    print(frame_info.function, frame_info.filename, frame_info.lineno)
# Out:
# <module> C:\Users\premt\AppData\Local\Temp\ipykernel_26948\3682732360.py 3
# run_code c:\Python313\Lib\site-packages\IPython\core\interactiveshell.py 3699
# run_ast_nodes c:\Python313\Lib\site-packages\IPython\core\interactiveshell.py 3639
# run_cell_async c:\Python313\Lib\site-packages\IPython\core\interactiveshell.py 3394
# _pseudo_sync_runner c:\Python313\Lib\site-packages\IPython\core\async_helpers.py 128
# _run_cell c:\Python313\Lib\site-packages\IPython\core\interactiveshell.py 3171
# run_cell c:\Python313\Lib\site-packages\IPython\core\interactiveshell.py 3116
# run_cell c:\Python313\Lib\site-packages\ipykernel\zmqshell.py 549
# do_execute c:\Python313\Lib\site-packages\ipykernel\ipkernel.py 449
# execute_request c:\Python313\Lib\site-packages\ipykernel\kernelbase.py 778
# execute_request c:\Python313\Lib\site-packages\ipykernel\ipkernel.py 362
# dispatch_shell c:\Python313\Lib\site-packages\ipykernel\kernelbase.py 437
# ...

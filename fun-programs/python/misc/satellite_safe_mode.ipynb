# %%
class SatelliteError(Exception):
    pass

class PowerFault(SatelliteError):
    pass

class AttitudeFault(SatelliteError):
    pass

class CommsFault(SatelliteError):
    pass

# %%
import random

def read_battery():
    level = random.uniform(10, 100)
    if level < 20:
        raise PowerFault(f"Battery Critically Low: {level:3.2f}%")
    return float(f"{level:3.2f}")

read_battery()
# Out:
# ---------------------------------------------------------------------------
# PowerFault                                Traceback (most recent call last)
# Cell In[25], line 9
#       6         raise PowerFault(f"Battery Critically Low: {level:3.2f}%")
#       7     return float(f"{level:3.2f}")
# ----> 9 read_battery()
#
# Cell In[25], line 6, in read_battery()
#       4 level = random.uniform(10, 100)
#       5 if level < 20:
# ----> 6     raise PowerFault(f"Battery Critically Low: {level:3.2f}%")
#       7 return float(f"{level:3.2f}")
#
# PowerFault: Battery Critically Low: 15.76%

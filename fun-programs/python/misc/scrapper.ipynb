# %%
import requests
import json
from bs4 import BeautifulSoup

base_url = "https://sxcontent9668.azureedge.us/cms-assets/job_posts.json"

# %%
try:
    response = requests.get(base_url)
    print(response.status_code)
    data = response.json()
    data_json_formatted = json.dumps(data, indent=4)
    print(data_json_formatted)
except Warning:
    print(f"Error fetching data - {response.status_code}")
# Out:
# 200
# [
#     {
#         "greenhouseId": 8084089002,
#         "title": "Inventory Specialist (Starlink) - 2nd Shift",
#         "location": "Woodinville, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8123850002,
#         "title": "New Graduate Engineer, Electrical (Starlink)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8133914002,
#         "title": "Material Transfer Driver (Starbase)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Supply Chain",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8136339002,
#         "title": "New Graduate Engineer, Electrical",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starshield"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8143964002,
#         "title": "New Graduate Engineer, Mechanical (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8143997002,
#         "title": "New Graduate Engineer, Propulsion (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8145483002,
#         "title": "New Graduate Engineer, Software",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starshield"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8148516002,
#         "title": "New Graduate Engineer, Mechanical (Starlink)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8148530002,
#         "title": "New Graduate Engineer, Electrical (Starlink)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8149015002,
#         "title": "Summer 2026 Business Operations Internship/Co-op",
#         "location": "Flexible - Any SpaceX Site",
#         "programs": [
#             "Falcon",
#             "Dragon",
#             "Starlink",
#             "Starship",
#             "Starshield",
#             "Corporate"
#         ],
#         "discipline": "College and University - Internships and Co-Ops",
#         "employementType": "Intern"
#     },
#     {
#         "greenhouseId": 8149124002,
#         "title": "Summer 2026 Engineering Internship/Co-op",
#         "location": "Flexible - Any SpaceX Site",
#         "programs": [
#             "Falcon",
#             "Dragon",
#             "Starlink",
#             "Starship",
#             "Starshield"
#         ],
#         "discipline": "College and University - Internships and Co-Ops",
#         "employementType": "Intern"
#     },
#     {
#         "greenhouseId": 8149154002,
#         "title": "Summer 2026 Software Engineering Internship/Co-op",
#         "location": "Flexible - Any SpaceX Site",
#         "programs": [
#             "Falcon",
#             "Dragon",
#             "Starlink",
#             "Starship",
#             "Starshield",
#             "Corporate"
#         ],
#         "discipline": "College and University - Internships and Co-Ops",
#         "employementType": "Intern"
#     },
#     {
#         "greenhouseId": 8149273002,
#         "title": "Summer 2026 Graduate Engineer",
#         "location": "Flexible - Any SpaceX Site",
#         "programs": [
#             "Falcon",
#             "Dragon",
#             "Starlink",
#             "Starship",
#             "Starshield",
#             "Corporate"
#         ],
#         "discipline": "College and University - Internships and Co-Ops",
#         "employementType": "Intern"
#     },
#     {
#         "greenhouseId": 8157963002,
#         "title": "Industrial Maintenance Technician (Starlink)  - 2nd Shift - Level 4/5",
#         "location": "Woodinville, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Facilities",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8160751002,
#         "title": "Manager, PCBA SMT Production (Starlink)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8161144002,
#         "title": "Sr. Software Engineer (Starship Quality)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8169934002,
#         "title": "Mechanical Engineer, Starship Launch Infrastructure (Gigabay)",
#         "location": "Cape Canaveral, FL",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8169979002,
#         "title": "Construction Superintendent, Starship Launch Infrastructure (Gigabay)",
#         "location": "Cape Canaveral, FL",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Facilities",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8186227002,
#         "title": "Propulsion Engineer, Development Operations (Raptor) ",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8186575002,
#         "title": "Sr. Software Engineer (Starshield)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starshield"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8188330002,
#         "title": "Sr. Partnerships Manager (Starlink Aviation)",
#         "location": "Woodinville, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Sales & Business Operations",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8188532002,
#         "title": "CMM Inspector (Starbase)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Supply Chain",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8190526002,
#         "title": "Summer 2026 Silicon Hardware Engineering Internship/Co-op",
#         "location": "Flexible - Any SpaceX Site",
#         "programs": [
#             "Falcon",
#             "Dragon",
#             "Starlink",
#             "Starship",
#             "Starshield",
#             "Corporate"
#         ],
#         "discipline": "College and University - Internships and Co-Ops",
#         "employementType": "Intern"
#     },
#     {
#         "greenhouseId": 8192168002,
#         "title": "Data Engineer, Ground Network Engineering (Gateway) ",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8193484002,
#         "title": "Build Supervisor (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8194455002,
#         "title": "Wastewater Engineer (Starlink)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Chemical & Materials",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8194799002,
#         "title": "Sr. Mechanical Design Engineer, Satellites (Starlink)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8194803002,
#         "title": "Build Engineer (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8194813002,
#         "title": "Integration Engineer (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8198528002,
#         "title": "Structures Technician (Vertical Barrel Integration) - Multiple Shifts",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8198752002,
#         "title": "Network Security Administrator",
#         "location": "Cape Canaveral, FL",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Engineering - Security",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8199669002,
#         "title": "Launch Reliability Engineer   ",
#         "location": "Vandenberg, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8199679002,
#         "title": "Tube Bender (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8199696002,
#         "title": "Production Operations Engineer (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8199734002,
#         "title": "Test Engineer (Starship) ",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8199766002,
#         "title": "Aerodynamics Engineer (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8199782002,
#         "title": "Pipe Welder (Prop Systems) ",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8199819002,
#         "title": "Build Specialist (Structures Engineering) ",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8200415002,
#         "title": "Manager, Security",
#         "location": "Vandenberg, CA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Physical Security",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8200452002,
#         "title": "Structures Technician (Falcon 9)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8201865002,
#         "title": "Security Engineer (Security Operations)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Engineering - Security",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8202185002,
#         "title": "Manufacturing Specialist (Starshield)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starshield"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8202235002,
#         "title": "Electrical Controls Engineer (Starlink)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8202260002,
#         "title": "Automation & Controls Specialist (Starlink Development)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8202292002,
#         "title": "Mechanical Engineer, Consumer Hardware (Starlink)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8202296002,
#         "title": "Sr. Electrical Controls Engineer (Starlink)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8202321002,
#         "title": "Sr. Mechanical Engineer, Consumer Hardware (Starlink)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8202351002,
#         "title": "Product Development Engineer (Starlink)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8202429002,
#         "title": "Tube Bender (Starship) - Level 4/5",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8202568002,
#         "title": "Sr. Automation Engineer (Starlink Growth)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Industrial & Operations",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8205076002,
#         "title": "Launch Engineer, Fluids (Starship)",
#         "location": "Cape Canaveral, FL",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8206159002,
#         "title": "Launch Engineer, Fluids (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8206645002,
#         "title": "Vehicle Controls Engineer (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8206849002,
#         "title": "Sr. Electrical Engineer (Starship Avionics)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8206888002,
#         "title": "Development Test Technician",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8206959002,
#         "title": "Launch Engineer, Falcon Engineering   ",
#         "location": "Vandenberg, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8206961002,
#         "title": "Integration & Test Engineer (Falcon)   ",
#         "location": "Vandenberg, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8206966002,
#         "title": "Integration & Test Engineer (Fairings)   ",
#         "location": "Vandenberg, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8206975002,
#         "title": "Launch Quality Inspector - 2nd Shift   ",
#         "location": "Vandenberg, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8207574002,
#         "title": "Hospitality Specialist",
#         "location": "Starbase, TX",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Food Services",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8207767002,
#         "title": "GNC Engineer (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8207833002,
#         "title": "Loads & Dynamics Engineer (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8207922002,
#         "title": "Propulsion Engineer, Thermal & Fluid Analysis (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208077002,
#         "title": "TIG Welder (Merlin)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208086002,
#         "title": "SMT Specialist - 2nd Shift   ",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208093002,
#         "title": "Propulsion Technician (Dragon)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Dragon"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208169002,
#         "title": "Composite Lamination Technician ",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208197002,
#         "title": "Integration & Test Engineer (Falcon 9)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208238002,
#         "title": "Software Engineer, Flight Software (Starship)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208339002,
#         "title": "Software Engineer, Flight Software (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208356002,
#         "title": "TIG Welder (Starship)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208646002,
#         "title": "Mechanical Engineer (Optical Test)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208656002,
#         "title": "GNC Engineer (Dragon)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Dragon"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208671002,
#         "title": "Sr. GNC Engineer (Dragon)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Dragon"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208677002,
#         "title": "NDE Level II Inspector",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "NonDestructive Evaluation",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208771002,
#         "title": "Production Project Engineer (Starlink)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208773002,
#         "title": "Process Technician, Stamping (Starlink)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208775002,
#         "title": "Network Security Engineer",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Engineering - Security",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208779002,
#         "title": "Security Engineer (Security Operations)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Engineering - Security",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208790002,
#         "title": "Propulsion Technician (COPV) - Multiple Shifts",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208792002,
#         "title": "Friction Stir Welding Technician (Tank Weldment)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208797002,
#         "title": "Components Build and Test Engineer (Falcon)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208806002,
#         "title": "Manufacturing Engineer (F9 Primary Structures/Integration)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8208998002,
#         "title": "TIG Welder (Transfer Tube) - Multiple Shifts",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8209000002,
#         "title": "Mechanical Engineer (Dragon)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Dragon"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8209601002,
#         "title": "Sr. Sourcing Specialist (Starlink Aviation)",
#         "location": "Woodinville, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Supply Chain",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8209636002,
#         "title": "Quality Inspector (Starlink Aviation)",
#         "location": "Woodinville, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8209788002,
#         "title": "Automation & Control Systems Technician",
#         "location": "McGregor, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8209826002,
#         "title": "Sr. Aerodynamics Engineer (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8209862002,
#         "title": "Sr. GNC Engineer (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8209884002,
#         "title": "Sr. Software Engineer, Flight Software (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8209903002,
#         "title": "Sr. Software Engineer, Flight Software (Starship)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8209915002,
#         "title": "Sr. Software Engineer, Security (Starship)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8209925002,
#         "title": "Sr. Thermal Engineer, Thermal & Fluid Analysis (Starship)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8209940002,
#         "title": "Thermal Engineer, Thermal & Fluid Analysis (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8209991002,
#         "title": "Site Reliability Engineer, GNC (Falcon)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8210122002,
#         "title": "Launch Engineer, Spacecraft Integration (Payloads)",
#         "location": "Vandenberg, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8210293002,
#         "title": "Enterprise Account Manager (Aviation)",
#         "location": "Woodinville, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Sales & Business Operations",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8210295002,
#         "title": "Engineering Specialist - 2nd Shift   ",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8210296002,
#         "title": "Manufacturing Engineering Specialist - 2nd Shift   ",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8210631002,
#         "title": "New Graduate Engineer, Mechanical (Cape Canaveral) ",
#         "location": "Cape Canaveral, FL",
#         "programs": [
#             "Falcon",
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8210995002,
#         "title": "Mechanical Engineer - Precision Machining (Starlink)",
#         "location": "Woodinville, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8211153002,
#         "title": "HVAC Technician - Level 4/5 (Starlink)",
#         "location": "Woodinville, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Facilities",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8211187002,
#         "title": "Software Engineer, Hardware Test & Automation (Optical Payloads)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8211293002,
#         "title": "Sr. Flight Reliability Engineer (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8211784002,
#         "title": "Electrical Engineer (Critical Infrastructure)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8211794002,
#         "title": "Sr. Construction Superintendent",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Facilities",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8211822002,
#         "title": "Application Software Engineer",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8211824002,
#         "title": "Application Software Engineer, Data - Top Secret Clearance",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8211826002,
#         "title": "Application Software Engineer",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8211878002,
#         "title": "Full Stack Software Engineer (Starlink Ground Network)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8211900002,
#         "title": "Electrical Engineer (Facilities)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8211916002,
#         "title": "Benefits Analyst (Workers Compensation)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Human Resources",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8213250002,
#         "title": "Software Engineer, Propulsion Simulation & Data Analysis",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8213305002,
#         "title": "Sr. Software Engineer, Propulsion Simulation & Data Analysis (Raptor)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8213424002,
#         "title": "Chemical Lab Technician (Starlink PCB)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8213433002,
#         "title": "Chemist (Starlink PCB)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8213698002,
#         "title": "Maintenance Technician (Starlink) - Level 4/5",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8213701002,
#         "title": "Network Engineer (Starlink)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Network Engineering & Operations",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8213708002,
#         "title": "Sr. Optical Network Engineer (Starlink)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Network Engineering & Operations",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8213720002,
#         "title": "Maintenance Engineer (Starlink)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8214125002,
#         "title": "Supplier Development Engineer (Starlink)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Industrial & Operations",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8214244002,
#         "title": "Avionics Integration & Test Technician (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8214252002,
#         "title": "Fire Protection Engineer (Starlink)   ",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Industrial & Operations",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8214365002,
#         "title": "GNC Engineer, Fleet Management (Starshield)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starshield"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8215027002,
#         "title": "Electromagnetic Environmental Effects Test Engineer",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8215212002,
#         "title": "Propulsion Technician (Falcon Valves)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8215236002,
#         "title": "Software Engineer (Components)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8215284002,
#         "title": "Propulsion Technician (Raptor)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8215916002,
#         "title": "Industrial Automation Engineer (Starlink)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8215953002,
#         "title": "NDE Inspector, Certified Welding Inspector (CWI)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8215985002,
#         "title": "Sr. Industrial Automation Engineer (Starlink)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8216029002,
#         "title": "Fluids Engineer (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8216045002,
#         "title": "Sr. Fluids Engineer (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8216065002,
#         "title": "Electrician (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8216528002,
#         "title": "Sr. Starship Engineer",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8216534002,
#         "title": "Mechanical Engineer, Machine Design (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8216643002,
#         "title": "Build Engineer, Structures (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8217432002,
#         "title": "Mechanical Engineer (Super Heavy Booster)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8217496002,
#         "title": "Operations Engineer (Starshield)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starshield"
#         ],
#         "discipline": "Engineering - Industrial & Operations",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8217533002,
#         "title": "Sr. Network Engineer (Starshield)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starshield"
#         ],
#         "discipline": "Network Engineering & Operations",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8217579002,
#         "title": "Turbomachinery Engineer (Raptor)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8217618002,
#         "title": "Sr. Turbomachinery Engineer (Raptor)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8217654002,
#         "title": "Launch Engineer, Mechanical/Fluids (Starship Launch Pad)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8217670002,
#         "title": "Mechanical Engineer, Mechazilla (Starship Launch Pad)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8217688002,
#         "title": "Development Test Specialist",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8217696002,
#         "title": "Development Test Engineer",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8217707002,
#         "title": "Mechanisms Test Engineer",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8217716002,
#         "title": "Mechanisms Engineer (Starship)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8217725002,
#         "title": "Mechanical Engineer (Starship Mechanisms)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8217772002,
#         "title": "Sr. Structural Engineer (Starship Launch Pad )",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8217919002,
#         "title": "Sr. Propulsion Engineer, Raptor Avionics (Interconnects) ",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8218090002,
#         "title": "Automation & Controls Engineer, Launch Pad (Starship)",
#         "location": "Cape Canaveral, FL",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8218276002,
#         "title": "GNC Engineer, Beam Planning",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starshield"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8218352002,
#         "title": "Thermal Development Technician (Starship) - Temporary",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Temporary"
#     },
#     {
#         "greenhouseId": 8218431002,
#         "title": "Sr. Satellite Policy Manager, APAC (Starlink)",
#         "location": "Singapore",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Government Affairs",
#         "employementType": "International"
#     },
#     {
#         "greenhouseId": 8218439002,
#         "title": "Ropes Access Technician (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8218441002,
#         "title": "Equipment Maintenance Technician (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8218447002,
#         "title": "Equipment Maintenance Technician (Starship) - Level 4/5",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8218449002,
#         "title": "Automation & Controls Engineer (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8218451002,
#         "title": "Electrical Engineer - Automation & Controls  (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8219280002,
#         "title": "Propulsion Technician (Raptor Foundry)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8219475002,
# ...
#     {
#         "greenhouseId": 8433799002,
#         "title": "Test Specialist (Starshield)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starshield"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8433873002,
#         "title": "Sr. Channel Marketing Manager (Starlink)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Marketing & Communications",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8433892002,
#         "title": "BIM Specialist",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Civil",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8433955002,
#         "title": "Global Supply Manager, Indirect",
#         "location": "McGregor, TX",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Supply Chain",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8434069002,
#         "title": "Production Coordinator (Booster Structures)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8434078002,
#         "title": "Global Logistics Specialist, Starlink",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Sales & Business Operations",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8434083002,
#         "title": "Sr. Product Sales Manager (Starlink)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Sales & Business Operations",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8434088002,
#         "title": "HVAC Programmer",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Facilities",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8434111002,
#         "title": "Shipping Specialist ",
#         "location": "Woodinville, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Sales & Business Operations",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8434141002,
#         "title": "Consumer Sales Operations Lead (Starlink)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Sales & Business Operations",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8434154002,
#         "title": "Starshield Enterprise Account Lead (Government) ",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starshield"
#         ],
#         "discipline": "Sales & Business Operations",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8434187002,
#         "title": "Officer Manager - Sunnyvale (Starlink)",
#         "location": "Sunnyvale, CA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Human Resources",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8434332002,
#         "title": "Integration Technician, Mission Management",
#         "location": "Vandenberg, CA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8434333002,
#         "title": "Integration Technician, Mission Management (2nd Shift)",
#         "location": "Vandenberg, CA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Engineering - Aerospace & Mechanical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8434363002,
#         "title": "Global Supply Manager, Contract Manufacturing (Starlink)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Supply Chain",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8434367002,
#         "title": "Sourcing Manager, Contract Manufacturing (Starlink)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Supply Chain",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8434411002,
#         "title": "Executive Assistant - Sunnyvale (Starlink)",
#         "location": "Sunnyvale, CA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Sales & Business Operations",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8434419002,
#         "title": "Metrology Specialist (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8434475002,
#         "title": "Hardware Reliability Specialist (Starlink)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8434520002,
#         "title": "Supervisor Tooling Operations (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8435646002,
#         "title": "Sr. Signal and Power Integrity Engineer, Satellites (Starlink)",
#         "location": "Sunnyvale, CA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8435675002,
#         "title": "Sr. SI/PI Engineer - Serdes, Satellites (Starlink)",
#         "location": "Sunnyvale, CA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8435946002,
#         "title": "Sr. Civil Engineer (Starship Launch Pad)",
#         "location": "Cape Canaveral, FL",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Civil",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8435949002,
#         "title": "Development Technician (Starlink) ",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8435953002,
#         "title": "CNC Machinist/Programmer (Starlink) ",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8436012002,
#         "title": "Internal Mobility Specialist (Recruiting)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Human Resources",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8436189002,
#         "title": "Sr. Ground Software Engineer, LabVIEW (Falcon & Dragon)",
#         "location": "McGregor, TX",
#         "programs": [
#             "Falcon",
#             "Dragon"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8436297002,
#         "title": "Global Operations Manager, Europe ",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Sales & Business Operations",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8436419002,
#         "title": "Sr. IT Windows Engineer",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Information Technology",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8436479002,
#         "title": " Production Technician (Starlink) - Entry Level ",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8436532002,
#         "title": "Accountant, Starlink",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Finance & Accounting",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8436568002,
#         "title": "Electrical Engineer, Power Systems (Starlink)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8436647002,
#         "title": "Deburr Technician (Machining) ",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Falcon"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8436728002,
#         "title": "Software Engineer, Product Development (Starshield)",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starshield"
#         ],
#         "discipline": "Engineering - Software & Analytics",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8436754002,
#         "title": "Sr. HR Investigator (Employee Relations)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Human Resources",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8436789002,
#         "title": "Support Technician (Starship) - Temporary ",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Temporary"
#     },
#     {
#         "greenhouseId": 8436801002,
#         "title": "Laser Production Technician (Starlink) - Entry Level ",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8436942002,
#         "title": "On-orbit Reliability Engineer, Satellites (Starlink)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8436944002,
#         "title": "Electrical Hardware Reliability Engineer, Satellites (Starlink)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8437612002,
#         "title": "Barista - Temporary ",
#         "location": "Cape Canaveral, FL",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Food Services",
#         "employementType": "Temporary"
#     },
#     {
#         "greenhouseId": 8437614002,
#         "title": "Fabrication Technician (Fluid Systems)",
#         "location": "Cape Canaveral, FL",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8437733002,
#         "title": "CNC Maintenance Technician (Starlink) - Level 4/5",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8437968002,
#         "title": "Quality Inspector (Starlink)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Supply Chain",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8438151002,
#         "title": "Sr. RF Silicon Software Engineer (Starlink)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Silicon",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8438312002,
#         "title": "Lead IT Systems Administrator, Launch",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Information Technology",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8438476002,
#         "title": "Technical Satellite Policy Analyst",
#         "location": "Washington, DC",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Government Affairs",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8438495002,
#         "title": "NDE Level II Inspector, Certified Welding Inspector (Starship Mechanisms) - 1st Shift",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Production",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8438598002,
#         "title": "Sr. IT Network Automation Engineer",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Information Technology",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8438659002,
#         "title": "Sr. IT Network Automation Engineer",
#         "location": "Redmond, WA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Information Technology",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8438665002,
#         "title": "Sr. IT Network Automation Engineer",
#         "location": "Cape Canaveral, FL",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Information Technology",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8438685002,
#         "title": "Sr. HR Investigator (Employee Relations)",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Human Resources",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8438713002,
#         "title": "Global Immigration & Compliance Manager",
#         "location": "Starbase, TX",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Human Resources",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8438725002,
#         "title": "Global Relocation Program Manager",
#         "location": "Hawthorne, CA",
#         "programs": [
#             "Corporate"
#         ],
#         "discipline": "Human Resources",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8439724002,
#         "title": "Sr. Global Sourcing Manager, Custom Silicon and Semiconductor (Starlink)",
#         "location": "Redmond, WA",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Supply Chain",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8440114002,
#         "title": "Sr. Welding Engineer (Starship)",
#         "location": "Starbase, TX",
#         "programs": [
#             "Starship"
#         ],
#         "discipline": "Engineering - Chemical & Materials",
#         "employementType": "Regular"
#     },
#     {
#         "greenhouseId": 8440651002,
#         "title": "Electrical Engineer, Energy Infrastructure & Generation",
#         "location": "Bastrop, TX",
#         "programs": [
#             "Starlink"
#         ],
#         "discipline": "Engineering - Electrical",
#         "employementType": "Regular"
#     }
# ]

# %%
for entry_dict in data:
    print(f"{entry_dict["title"].ljust(95)} | {str(entry_dict["programs"][:]).ljust(100)}")
# Out:
# Inventory Specialist (Starlink) - 2nd Shift                                                     | ['Starlink']
# New Graduate Engineer, Electrical (Starlink)                                                    | ['Starlink']
# Material Transfer Driver (Starbase)                                                             | ['Starship']
# New Graduate Engineer, Electrical                                                               | ['Starshield']
# New Graduate Engineer, Mechanical (Starship)                                                    | ['Starship']
# New Graduate Engineer, Propulsion (Starship)                                                    | ['Starship']
# New Graduate Engineer, Software                                                                 | ['Starshield']
# New Graduate Engineer, Mechanical (Starlink)                                                    | ['Starlink']
# New Graduate Engineer, Electrical (Starlink)                                                    | ['Starlink']
# Summer 2026 Business Operations Internship/Co-op                                                | ['Falcon', 'Dragon', 'Starlink', 'Starship', 'Starshield', 'Corporate']
# Summer 2026 Engineering Internship/Co-op                                                        | ['Falcon', 'Dragon', 'Starlink', 'Starship', 'Starshield']
# Summer 2026 Software Engineering Internship/Co-op                                               | ['Falcon', 'Dragon', 'Starlink', 'Starship', 'Starshield', 'Corporate']
# Summer 2026 Graduate Engineer                                                                   | ['Falcon', 'Dragon', 'Starlink', 'Starship', 'Starshield', 'Corporate']
# Industrial Maintenance Technician (Starlink)  - 2nd Shift - Level 4/5                           | ['Starlink']
# Manager, PCBA SMT Production (Starlink)                                                         | ['Starlink']
# Sr. Software Engineer (Starship Quality)                                                        | ['Starship']
# Mechanical Engineer, Starship Launch Infrastructure (Gigabay)                                   | ['Starship']
# Construction Superintendent, Starship Launch Infrastructure (Gigabay)                           | ['Starship']
# Propulsion Engineer, Development Operations (Raptor)                                            | ['Starship']
# Sr. Software Engineer (Starshield)                                                              | ['Starshield']
# Sr. Partnerships Manager (Starlink Aviation)                                                    | ['Starlink']
# CMM Inspector (Starbase)                                                                        | ['Starship']
# Summer 2026 Silicon Hardware Engineering Internship/Co-op                                       | ['Falcon', 'Dragon', 'Starlink', 'Starship', 'Starshield', 'Corporate']
# Data Engineer, Ground Network Engineering (Gateway)                                             | ['Starlink']
# Build Supervisor (Starship)                                                                     | ['Starship']
# Wastewater Engineer (Starlink)                                                                  | ['Starlink']
# Sr. Mechanical Design Engineer, Satellites (Starlink)                                           | ['Starlink']
# Build Engineer (Starship)                                                                       | ['Starship']
# Integration Engineer (Starship)                                                                 | ['Starship']
# Structures Technician (Vertical Barrel Integration) - Multiple Shifts                           | ['Falcon']
# Network Security Administrator                                                                  | ['Corporate']
# Launch Reliability Engineer                                                                     | ['Falcon']
# Tube Bender (Starship)                                                                          | ['Starship']
# Production Operations Engineer (Starship)                                                       | ['Starship']
# Test Engineer (Starship)                                                                        | ['Starship']
# Aerodynamics Engineer (Starship)                                                                | ['Starship']
# Pipe Welder (Prop Systems)                                                                      | ['Starship']
# Build Specialist (Structures Engineering)                                                       | ['Starship']
# Manager, Security                                                                               | ['Corporate']
# Structures Technician (Falcon 9)                                                                | ['Falcon']
# Security Engineer (Security Operations)                                                         | ['Corporate']
# Manufacturing Specialist (Starshield)                                                           | ['Starshield']
# Electrical Controls Engineer (Starlink)                                                         | ['Starlink']
# Automation & Controls Specialist (Starlink Development)                                         | ['Starlink']
# Mechanical Engineer, Consumer Hardware (Starlink)                                               | ['Starlink']
# Sr. Electrical Controls Engineer (Starlink)                                                     | ['Starlink']
# Sr. Mechanical Engineer, Consumer Hardware (Starlink)                                           | ['Starlink']
# Product Development Engineer (Starlink)                                                         | ['Starlink']
# Tube Bender (Starship) - Level 4/5                                                              | ['Starship']
# Sr. Automation Engineer (Starlink Growth)                                                       | ['Starlink']
# Launch Engineer, Fluids (Starship)                                                              | ['Starship']
# Launch Engineer, Fluids (Starship)                                                              | ['Starship']
# Vehicle Controls Engineer (Starship)                                                            | ['Starship']
# Sr. Electrical Engineer (Starship Avionics)                                                     | ['Starship']
# Development Test Technician                                                                     | ['Starship']
# Launch Engineer, Falcon Engineering                                                             | ['Falcon']
# Integration & Test Engineer (Falcon)                                                            | ['Falcon']
# Integration & Test Engineer (Fairings)                                                          | ['Falcon']
# Launch Quality Inspector - 2nd Shift                                                            | ['Falcon']
# Hospitality Specialist                                                                          | ['Corporate']
# GNC Engineer (Starship)                                                                         | ['Starship']
# Loads & Dynamics Engineer (Starship)                                                            | ['Starship']
# Propulsion Engineer, Thermal & Fluid Analysis (Starship)                                        | ['Starship']
# TIG Welder (Merlin)                                                                             | ['Falcon']
# SMT Specialist - 2nd Shift                                                                      | ['Starlink']
# Propulsion Technician (Dragon)                                                                  | ['Dragon']
# Composite Lamination Technician                                                                 | ['Falcon']
# Integration & Test Engineer (Falcon 9)                                                          | ['Falcon']
# Software Engineer, Flight Software (Starship)                                                   | ['Starship']
# Software Engineer, Flight Software (Starship)                                                   | ['Starship']
# TIG Welder (Starship)                                                                           | ['Starship']
# Mechanical Engineer (Optical Test)                                                              | ['Starlink']
# GNC Engineer (Dragon)                                                                           | ['Dragon']
# Sr. GNC Engineer (Dragon)                                                                       | ['Dragon']
# NDE Level II Inspector                                                                          | ['Falcon']
# Production Project Engineer (Starlink)                                                          | ['Starlink']
# Process Technician, Stamping (Starlink)                                                         | ['Starlink']
# Network Security Engineer                                                                       | ['Corporate']
# Security Engineer (Security Operations)                                                         | ['Corporate']
# Propulsion Technician (COPV) - Multiple Shifts                                                  | ['Falcon']
# Friction Stir Welding Technician (Tank Weldment)                                                | ['Falcon']
# Components Build and Test Engineer (Falcon)                                                     | ['Falcon']
# Manufacturing Engineer (F9 Primary Structures/Integration)                                      | ['Falcon']
# TIG Welder (Transfer Tube) - Multiple Shifts                                                    | ['Falcon']
# Mechanical Engineer (Dragon)                                                                    | ['Dragon']
# Sr. Sourcing Specialist (Starlink Aviation)                                                     | ['Starlink']
# Quality Inspector (Starlink Aviation)                                                           | ['Starlink']
# Automation & Control Systems Technician                                                         | ['Starship']
# Sr. Aerodynamics Engineer (Starship)                                                            | ['Starship']
# Sr. GNC Engineer (Starship)                                                                     | ['Starship']
# Sr. Software Engineer, Flight Software (Starship)                                               | ['Starship']
# Sr. Software Engineer, Flight Software (Starship)                                               | ['Starship']
# Sr. Software Engineer, Security (Starship)                                                      | ['Starship']
# Sr. Thermal Engineer, Thermal & Fluid Analysis (Starship)                                       | ['Starship']
# Thermal Engineer, Thermal & Fluid Analysis (Starship)                                           | ['Starship']
# Site Reliability Engineer, GNC (Falcon)                                                         | ['Falcon']
# Launch Engineer, Spacecraft Integration (Payloads)                                              | ['Falcon']
# Enterprise Account Manager (Aviation)                                                           | ['Starlink']
# Engineering Specialist - 2nd Shift                                                              | ['Starlink']
# Manufacturing Engineering Specialist - 2nd Shift                                                | ['Starlink']
# New Graduate Engineer, Mechanical (Cape Canaveral)                                              | ['Falcon', 'Starship']
# Mechanical Engineer - Precision Machining (Starlink)                                            | ['Starlink']
# HVAC Technician - Level 4/5 (Starlink)                                                          | ['Starlink']
# Software Engineer, Hardware Test & Automation (Optical Payloads)                                | ['Starlink']
# Sr. Flight Reliability Engineer (Starship)                                                      | ['Starship']
# Electrical Engineer (Critical Infrastructure)                                                   | ['Corporate']
# Sr. Construction Superintendent                                                                 | ['Corporate']
# Application Software Engineer                                                                   | ['Corporate']
# Application Software Engineer, Data - Top Secret Clearance                                      | ['Corporate']
# Application Software Engineer                                                                   | ['Corporate']
# Full Stack Software Engineer (Starlink Ground Network)                                          | ['Starlink']
# Electrical Engineer (Facilities)                                                                | ['Corporate']
# Benefits Analyst (Workers Compensation)                                                         | ['Corporate']
# Software Engineer, Propulsion Simulation & Data Analysis                                        | ['Starship']
# Sr. Software Engineer, Propulsion Simulation & Data Analysis (Raptor)                           | ['Starship']
# Chemical Lab Technician (Starlink PCB)                                                          | ['Starlink']
# Chemist (Starlink PCB)                                                                          | ['Starlink']
# Maintenance Technician (Starlink) - Level 4/5                                                   | ['Starlink']
# Network Engineer (Starlink)                                                                     | ['Starlink']
# Sr. Optical Network Engineer (Starlink)                                                         | ['Starlink']
# Maintenance Engineer (Starlink)                                                                 | ['Starlink']
# Supplier Development Engineer (Starlink)                                                        | ['Starlink']
# Avionics Integration & Test Technician (Starship)                                               | ['Starship']
# Fire Protection Engineer (Starlink)                                                             | ['Starlink']
# GNC Engineer, Fleet Management (Starshield)                                                     | ['Starshield']
# Electromagnetic Environmental Effects Test Engineer                                             | ['Starlink']
# Propulsion Technician (Falcon Valves)                                                           | ['Falcon']
# Software Engineer (Components)                                                                  | ['Starship']
# Propulsion Technician (Raptor)                                                                  | ['Starship']
# Industrial Automation Engineer (Starlink)                                                       | ['Starlink']
# NDE Inspector, Certified Welding Inspector (CWI)                                                | ['Starship']
# Sr. Industrial Automation Engineer (Starlink)                                                   | ['Starlink']
# Fluids Engineer (Starship)                                                                      | ['Starship']
# Sr. Fluids Engineer (Starship)                                                                  | ['Starship']
# Electrician (Starship)                                                                          | ['Starship']
# Sr. Starship Engineer                                                                           | ['Starship']
# Mechanical Engineer, Machine Design (Starship)                                                  | ['Starship']
# Build Engineer, Structures (Starship)                                                           | ['Starship']
# Mechanical Engineer (Super Heavy Booster)                                                       | ['Starship']
# Operations Engineer (Starshield)                                                                | ['Starshield']
# Sr. Network Engineer (Starshield)                                                               | ['Starshield']
# Turbomachinery Engineer (Raptor)                                                                | ['Starship']
# Sr. Turbomachinery Engineer (Raptor)                                                            | ['Starship']
# Launch Engineer, Mechanical/Fluids (Starship Launch Pad)                                        | ['Starship']
# Mechanical Engineer, Mechazilla (Starship Launch Pad)                                           | ['Starship']
# Development Test Specialist                                                                     | ['Starship']
# Development Test Engineer                                                                       | ['Starship']
# Mechanisms Test Engineer                                                                        | ['Starship']
# Mechanisms Engineer (Starship)                                                                  | ['Starship']
# Mechanical Engineer (Starship Mechanisms)                                                       | ['Starship']
# Sr. Structural Engineer (Starship Launch Pad )                                                  | ['Starship']
# Sr. Propulsion Engineer, Raptor Avionics (Interconnects)                                        | ['Starship']
# Automation & Controls Engineer, Launch Pad (Starship)                                           | ['Starship']
# GNC Engineer, Beam Planning                                                                     | ['Starshield']
# Thermal Development Technician (Starship) - Temporary                                           | ['Starship']
# Sr. Satellite Policy Manager, APAC (Starlink)                                                   | ['Starlink']
# Ropes Access Technician (Starship)                                                              | ['Starship']
# Equipment Maintenance Technician (Starship)                                                     | ['Starship']
# Equipment Maintenance Technician (Starship) - Level 4/5                                         | ['Starship']
# Automation & Controls Engineer (Starship)                                                       | ['Starship']
# Electrical Engineer - Automation & Controls  (Starship)                                         | ['Starship']
# Propulsion Technician (Raptor Foundry)                                                          | ['Starship']
# Sr. RFIC Design Engineer                                                                        | ['Starshield']
# Supplier Quality Specialist (Starlink)                                                          | ['Starlink']
# Security Officer 3 - Night Shift                                                                | ['Corporate']
# CNC Machinist, Thermal Development (Starship)                                                   | ['Starship']
# Hardware Development Engineer, Gateway Failure Analysis (Starlink)                              | ['Starlink']
# Electrical Test and Reliability Engineer, Gateways (Starlink)                                   | ['Starlink']
# Sr. Thermal Hardware Engineer (Dragon)                                                          | ['Dragon']
# Automation & Controls Specialist (Starship)                                                     | ['Starship']
# SCADA Specialist - Automation & Controls (Starship)                                             | ['Starship']
# Automation & Controls Technician (Starship)                                                     | ['Starship']
# Manufacturing Engineer - Build Reliability (Starship)                                           | ['Starship']
# Build Reliability Engineer (Starship) - Welding                                                 | ['Starship']
# Sr. Automation & Controls Engineer (Starship)                                                   | ['Starship']
# Supervisor, NDE Operations (Starship) - Nights                                                  | ['Starship']
# NDE Inspector Level II (Starship)                                                               | ['Starship']
# NDE Inspector Level II - Phased Array Ultrasonic Testing (PAUT) (Starship)                      | ['Starship']
# NDE Inspector Level II - Digital/Computed Radiography (Starship)                                | ['Starship']
# Self-Propelled Modular Transporter (SPMT) Maintenance Specialist (Starship)                     | ['Starship']
# Spaceport Designer, Architect                                                                   | ['Starship']
# Fleet Maintenance Technician (Starship) - Level 4/5                                             | ['Starship']
# Fleet Maintenance Technician (Starship)                                                         | ['Starship']
# Critical Lift Technician (Starship)                                                             | ['Starship']
# Critical Lift Supervisor - Night Shift                                                          | ['Starship']
# Software Engineer (Starship Quality)                                                            | ['Starship']
# Plumber                                                                                         | ['Corporate']
# Food Services Specialist - Temporary                                                            | ['Corporate']
# Cook - Temporary                                                                                | ['Corporate']
# Facilities Technician                                                                           | ['Corporate']
# Cook                                                                                            | ['Corporate']
# Hardware Test Engineer (Starlink)                                                               | ['Starlink']
# Equipment Reliability Engineer (Starlink)                                                       | ['Starlink']
# Sourcing Manager, PCB (Starlink)                                                                | ['Starlink']
# Welder                                                                                          | ['Starship']
# Software Engineer (Thermal & Fluid Analysis)                                                    | ['Starship']
# Propulsion Engineer (Merlin Flight Operations)                                                  | ['Falcon']
# Paint Technician (Falcon 9) - Multiple Shifts                                                   | ['Falcon']
# Electrician                                                                                     | ['Corporate']
# Manufacturing Engineer (Merlin Turbopumps & Injectors)                                          | ['Falcon']
# Electrical Test Engineer (Avionics)                                                             | ['Falcon']
# Video Editor II                                                                                 | ['Corporate']
# Supervisor, Welding (Starship)                                                                  | ['Starship']
# Colorist/Video Finishing Artist II                                                              | ['Corporate']
# Production Sound Mixer                                                                          | ['Corporate']
# Production Sound Mixer                                                                          | ['Corporate']
# Software Engineer, PCBA (Starlink)                                                              | ['Starlink']
# PCB Designer (Starlink)                                                                         | ['Starlink']
# PCB Designer (Starlink)                                                                         | ['Starlink']
# Software Engineer, Test Engineering and Operations                                              | ['Falcon']
# Mechanical Engineer, Falcon Launch Systems                                                      | ['Falcon']
# Manager, Gateway Electronics Engineering (Starlink)                                             | ['Starlink']
# Network Automation Engineer (Starshield)                                                        | ['Starshield']
# Security Software Engineer (Starshield)                                                         | ['Starshield']
# Sr. Network Engineer (Starshield)                                                               | ['Starshield']
# Sr. Electrical Test and Reliability Engineer, Gateways (Starlink)                               | ['Starlink']
# Deburr Technician, Machining (Starship)                                                         | ['Starship']
# Deburr Technician, Machining (Starship) - 2nd Shift                                             | ['Starship']
# CNC Machinist (Starship Components) - Level 4/5                                                 | ['Starship']
# Supervisor, Machining (Starship Components)                                                     | ['Starship']
# Mission Integration Engineer, NSSL                                                              | ['Corporate']
# Sr. Mission Integration Engineer, Starship Crew & Cargo Programs                                | ['Corporate']
# Mission Manager, Starship Crew and Cargo Programs                                               | ['Starship']
# Integration Technician (Starship) - Level 4/5                                                   | ['Starship']
# Supervisor, Facilities (Starlink) - 2nd Shift                                                   | ['Starlink']
# Sr. Real Estate Analyst                                                                         | ['Corporate']
# Launch Engineer, Mechanical                                                                     | ['Starship']
# IC Packaging Test Engineer, Silicon Technology (Starlink)                                       | ['Starlink']
# Electrical Engineer, Facilities (Starlink)                                                      | ['Starlink']
# Supervisor, Starlink Customer Support - Multiple Shifts                                         | ['Starlink']
# Supervisor, Starlink Customer Support - Night Shift                                             | ['Starlink']
# Supervisor, Starlink Customer Support - Weekend Shift                                           | ['Starlink']
# CNC Machine Maintenance Technician (Starlink)                                                   | ['Starlink']
# Consumer Sales Manager, LATAM Sales (Starlink)                                                  | ['Starlink']
# Sr. Hardware Development Engineer, Gateway Failure Analysis (Starlink)                          | ['Starlink']
# Principal IC Packaging Test Engineer, Silicon Technology (Starlink)                             | ['Starlink']
# Build Reliability Engineer (Starship) - Test                                                    | ['Starship']
# Automation & Controls Engineer (Starship Launch Pad)                                            | ['Starship']
# Lead Hardware Reliability Engineer (Starlink Aviation)                                          | ['Starlink']
# Propulsion Engineer (Raptor Combustion Devices)                                                 | ['Starship']
# Launch Pad Technician (Starship) - Day Shift                                                    | ['Starship']
# ...
# Consumer Sales Operations Analyst (Starlink)                                                    | ['Starlink']
# Manufacturing Engineer (CNC Machining)                                                          | ['Falcon']
# Structures Technician (Machining)                                                               | ['Falcon']
# Toolmaker - 2nd shift (Level 4/5)                                                               | ['Falcon']
# Sr. Process Engineer (Starlink)                                                                 | ['Starlink']
# Aviation Development Engineer (Starlink)                                                        | ['Starlink']
# Senior Sourcing Specialist, Installer Network (Starlink)                                        | ['Starlink']
# NDE Engineer, Supply Chain                                                                      | ['Corporate']
# Integration & Test Specialist (Starlink Satellite Integration) - 2nd Shift                      | ['Starlink']
# Sr. Tax Analyst                                                                                 | ['Corporate']
# Launch Engineer, Command & Control Systems                                                      | ['Falcon']
# Launch Engineer, Instrumentation                                                                | ['Falcon']
# Production Coordinator - 2nd Shift Weekday                                                      | ['Falcon']
# Mission Manager, Rideshare                                                                      | ['Falcon']
# NDE Auditor/Trainer II (Starship)                                                               | ['Starship']
# Lead, NDE Audit & Certification (Starship)                                                      | ['Starship']
# Sr. NDE Engineer, Supply Chain                                                                  | ['Corporate']
# Environmental Health & Safety Technician                                                        | ['Corporate']
# Manager, IT Systems (Applications & Operations)                                                 | ['Corporate']
# Manager, Environmental Health & Safety (Process Safety)                                         | ['Corporate']
# Sr. Propulsion Engineer, Development Operations (Raptor)                                        | ['Starship']
# Global Operations Manager, Latin America                                                        | ['Starlink']
# Sr. Materials Engineer, Silicon Wafer Engineering (Starlink)                                    | ['Starlink']
# Fabrication Design Development Technician (Starlink)                                            | ['Starlink']
# Test Specialist (Starshield)                                                                    | ['Starshield']
# Sr. Channel Marketing Manager (Starlink)                                                        | ['Starlink']
# BIM Specialist                                                                                  | ['Starlink']
# Global Supply Manager, Indirect                                                                 | ['Corporate']
# Production Coordinator (Booster Structures)                                                     | ['Starship']
# Global Logistics Specialist, Starlink                                                           | ['Starlink']
# Sr. Product Sales Manager (Starlink)                                                            | ['Starlink']
# HVAC Programmer                                                                                 | ['Starlink']
# Shipping Specialist                                                                             | ['Starlink']
# Consumer Sales Operations Lead (Starlink)                                                       | ['Starlink']
# Starshield Enterprise Account Lead (Government)                                                 | ['Starshield']
# Officer Manager - Sunnyvale (Starlink)                                                          | ['Starlink']
# Integration Technician, Mission Management                                                      | ['Corporate']
# Integration Technician, Mission Management (2nd Shift)                                          | ['Corporate']
# Global Supply Manager, Contract Manufacturing (Starlink)                                        | ['Starlink']
# Sourcing Manager, Contract Manufacturing (Starlink)                                             | ['Starlink']
# Executive Assistant - Sunnyvale (Starlink)                                                      | ['Starlink']
# Metrology Specialist (Starship)                                                                 | ['Starship']
# Hardware Reliability Specialist (Starlink)                                                      | ['Starlink']
# Supervisor Tooling Operations (Starship)                                                        | ['Starship']
# Sr. Signal and Power Integrity Engineer, Satellites (Starlink)                                  | ['Starlink']
# Sr. SI/PI Engineer - Serdes, Satellites (Starlink)                                              | ['Starlink']
# Sr. Civil Engineer (Starship Launch Pad)                                                        | ['Starship']
# Development Technician (Starlink)                                                               | ['Starlink']
# CNC Machinist/Programmer (Starlink)                                                             | ['Starlink']
# Internal Mobility Specialist (Recruiting)                                                       | ['Corporate']
# Sr. Ground Software Engineer, LabVIEW (Falcon & Dragon)                                         | ['Falcon', 'Dragon']
# Global Operations Manager, Europe                                                               | ['Starlink']
# Sr. IT Windows Engineer                                                                         | ['Corporate']
#  Production Technician (Starlink) - Entry Level                                                 | ['Starlink']
# Accountant, Starlink                                                                            | ['Corporate']
# Electrical Engineer, Power Systems (Starlink)                                                   | ['Starlink']
# Deburr Technician (Machining)                                                                   | ['Falcon']
# Software Engineer, Product Development (Starshield)                                             | ['Starshield']
# Sr. HR Investigator (Employee Relations)                                                        | ['Corporate']
# Support Technician (Starship) - Temporary                                                       | ['Starship']
# Laser Production Technician (Starlink) - Entry Level                                            | ['Starlink']
# On-orbit Reliability Engineer, Satellites (Starlink)                                            | ['Starlink']
# Electrical Hardware Reliability Engineer, Satellites (Starlink)                                 | ['Starlink']
# Barista - Temporary                                                                             | ['Corporate']
# Fabrication Technician (Fluid Systems)                                                          | ['Starship']
# CNC Maintenance Technician (Starlink) - Level 4/5                                               | ['Starlink']
# Quality Inspector (Starlink)                                                                    | ['Starlink']
# Sr. RF Silicon Software Engineer (Starlink)                                                     | ['Starlink']
# Lead IT Systems Administrator, Launch                                                           | ['Corporate']
# Technical Satellite Policy Analyst                                                              | ['Starlink']
# NDE Level II Inspector, Certified Welding Inspector (Starship Mechanisms) - 1st Shift           | ['Starship']
# Sr. IT Network Automation Engineer                                                              | ['Corporate']
# Sr. IT Network Automation Engineer                                                              | ['Corporate']
# Sr. IT Network Automation Engineer                                                              | ['Corporate']
# Sr. HR Investigator (Employee Relations)                                                        | ['Corporate']
# Global Immigration & Compliance Manager                                                         | ['Corporate']
# Global Relocation Program Manager                                                               | ['Corporate']
# Sr. Global Sourcing Manager, Custom Silicon and Semiconductor (Starlink)                        | ['Starlink']
# Sr. Welding Engineer (Starship)                                                                 | ['Starship']
# Electrical Engineer, Energy Infrastructure & Generation                                         | ['Starlink']

# %%
max_len = float('-inf')
for entry_dict in data:
    if len(entry_dict["title"]) > max_len:
        max_len = len(entry_dict["title"])

print(max_len)
# Out:
# 90

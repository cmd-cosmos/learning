# %%
import requests
import json
from bs4 import BeautifulSoup

base_url = "https://sxcontent9668.azureedge.us/cms-assets/job_posts.json"

# %%
response = requests.get(base_url)
text_resp = response.text

text_resp
# Out:
# '[{"greenhouseId":8084089002,"title":"Inventory Specialist (Starlink) - 2nd Shift","location":"Woodinville, WA","programs":["Starlink"],"discipline":"Production","employementType":"Regular"},{"greenhouseId":8123850002,"title":"New Graduate Engineer, Electrical (Starlink)","location":"Redmond, WA","programs":["Starlink"],"discipline":"Engineering - Electrical","employementType":"Regular"},{"greenhouseId":8133914002,"title":"Material Transfer Driver (Starbase)","location":"Starbase, TX","programs":["Starship"],"discipline":"Supply Chain","employementType":"Regular"},{"greenhouseId":8136339002,"title":"New Graduate Engineer, Electrical","location":"Hawthorne, CA","programs":["Starshield"],"discipline":"Engineering - Electrical","employementType":"Regular"},{"greenhouseId":8143964002,"title":"New Graduate Engineer, Mechanical (Starship)","location":"Starbase, TX","programs":["Starship"],"discipline":"Engineering - Aerospace \\u0026 Mechanical","employementType":"Regular"},{"greenhouseId":8143997002,"title":"New Graduate Engineer, Propulsion (Starship)","location":"Starbase, TX","programs":["Starship"],"discipline":"Engineering - Aerospace \\u0026 Mechanical","employementType":"Regular"},{"greenhouseId":8145483002,"title":"New Graduate Engineer, Software","location":"Hawthorne, CA","programs":["Starshield"],"discipline":"Engineering - Software \\u0026 Analytics","employementType":"Regular"},{"greenhouseId":8148516002,"title":"New Graduate Engineer, Mechanical (Starlink)","location":"Bastrop, TX","programs":["Starlink"],"discipline":"Engineering - Aerospace \\u0026 Mechanical","employementType":"Regular"},{"greenhouseId":8148530002,"title":"New Graduate Engineer, Electrical (Starlink)","location":"Bastrop, TX","programs":["Starlink"],"discipline":"Engineering - Electrical","employementType":"Regular"},{"greenhouseId":8149015002,"title":"Summer 2026 Business Operations Internship/Co-op","location":"Flexible - Any SpaceX Site","programs":["Falcon","Dragon","Starlink","Starship","Starshield","Corporate"],"discipline":"College and University - Internships and Co-Ops","employementType":"Intern"},{"greenhouseId":8149124002,"title":"Summer 2026 Engineering Internship/Co-op","location":"Flexible - Any SpaceX Site","programs":["Falcon","Dragon","Starlink","Starship","Starshield"],"discipline":"College and University - Internships and Co-Ops","employementType":"Intern"},{"greenhouseId":8149154002,"title":"Summer 2026 Software Engineering Internship/Co-op","location":"Flexible - Any SpaceX Site","programs":["Falcon","Dragon","Starlink","Starship","Starshield","Corporate"],"discipline":"College and University - Internships and Co-Ops","employementType":"Intern"},{"greenhouseId":8149273002,"title":"Summer 2026 Graduate Engineer","location":"Flexible - Any SpaceX Site","programs":["Falcon","Dragon","Starlink","Starship","Starshield","Corporate"],"discipline":"College and University - Internships and Co-Ops","employementType":"Intern"},{"greenhouseId":8157963002,"title":"Industrial Maintenance Technician (Starlink)  - 2nd Shift - Level 4/5","location":"Woodinville, WA","programs":["Starlink"],"discipline":"Facilities","employementType":"Regular"},{"greenhouseId":8160751002,"title":"Manager, PCBA SMT Production (Starlink)","location":"Bastrop, TX","programs":["Starlink"],"discipline":"Production","employementType":"Regular"},{"greenhouseId":8161144002,"title":"Sr. Software Engineer (Starship Quality)","location":"Starbase, TX","programs":["Starship"],"discipline":"Engineering - Software \\u0026 Analytics","employementType":"Regular"},{"greenhouseId":8169934002,"title":"Mechanical Engineer, Starship Launch Infrastructure (Gigabay)","location":"Cape Canaveral, FL","programs":["Starship"],"discipline":"Engineering - Aerospace \\u0026 Mechanical","employementType":"Regular"},{"greenhouseId":8169979002,"title":"Construction Superintendent, Starship Launch Infrastructure (Gigabay)","location":"Cape Canaveral, FL","programs":["Starship"],"discipline":"Fac ...

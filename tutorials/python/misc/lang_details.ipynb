# %%
# names vs values --> assignment and binding similarity
# assignment does not copy vals
# names bind to objects

a = [1,2,3]
b = a

b.append(4)

print("a = ", a)
print("b = ", b)

print("id a = ",id(a))
print("id b = ",id(b))

print(a is b)
# Out:
# a =  [1, 2, 3, 4]
# b =  [1, 2, 3, 4]
# id a =  1935105222528
# id b =  1935105222528
# True

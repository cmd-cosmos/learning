# %%
import sqlite3
import pandas as pd

# %%
# in memory db
conn = sqlite3.connect(":memory:")
cur = conn.cursor()

# %%
cur.execute("""
CREATE TABLE customers (id INTEGER PRIMARY KEY, name TEXT, age INTEGER, amount REAL)
""")

# %%
conn.commit()

# %%
import numpy as np

# %%
# standardization

x = np.array([
    [10 ,200],
    [60 ,180],
    [100 ,2000]
])

x_std = (x - x.mean(axis=0)) / x.std(axis=0)
print(x_std, end="\n\n")
print(x_std.mean(), end="\n\n") # almost 0 mean
print(x_std.std(), end="\n\n")  # std dev = 1
# Out:
# [[-1.26750044 -0.69535494]
#  [ 0.09053575 -0.71879387]
#  [ 1.1769647   1.41414882]]
#
# 7.401486830834377e-17
#
# 1.0

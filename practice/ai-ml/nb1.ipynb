# %%
import numpy as np
import pandas as pd

# %%
# arrays

arr = np.array([1,2,3]) # rank = 1
print(type(arr))
print(arr.shape)
print(arr[0], arr[2])
arr[0] = np.zeros(1)
print(arr)
# Out:
# <class 'numpy.ndarray'>
# (3,)
# 1 3
# [0 2 3]
# C:\Users\premt\AppData\Local\Temp\ipykernel_27956\3123842716.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   arr[0] = np.zeros(1)

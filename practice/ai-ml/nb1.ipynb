# %%
import warnings
import numpy as np
import pandas as pd

warnings.filterwarnings("ignore")

# %%
# arrays

arr = np.array([1,2,3]) # rank = 1
print(type(arr))
print(arr.shape)
print(arr[0], arr[2])
arr[0] = np.zeros(1)
print(arr)
# Out:
# <class 'numpy.ndarray'>
# (3,)
# 1 3
# [0 2 3]

# %%
# rank 2 array

b = np.array([[1,2], [3,4]])
print(b)
print(b.shape)
print(type(b))

for rows in b:
    print(rows)

print(b[0, 1]) # value in the 0th row and 1st col
# Out:
# [[1 2]
#  [3 4]]
# (2, 2)
# <class 'numpy.ndarray'>
# [1 2]
# [3 4]
# 2
